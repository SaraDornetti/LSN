# %% [markdown]
# # <span style="color:firebrick"> Laboratorio di simulazione numerica </span>

# %% [markdown]
# ## <span style="color:firebrick"> Esercizio 1.1 </span>
# Test the Pseudo-Random Number generator downloaded from the NSL Ariel web site by estimating:
# 1. $\langle r \rangle = \int_0^1 r dr = 1/2$. <font color="red">Make a picture of the estimation of $\langle r \rangle$ and its uncertainty (which corresponds to Standard Deviation of the mean for the estimation of $\langle r \rangle$) with a large number of *throws* $M$ (e.g. $M\ge 10^4$) as a function of the number of blocks, $N$</font> (see below: Computing statistical uncertainties).

# %%
import numpy as np
import matplotlib.pyplot as plt

# Carica i dati
data = np.loadtxt("output.txt")  
media = data[:, 0]-0.5  # Prima colonna (media)
err = data[:, 1]  # Seconda colonna (errore)

# Crea un array per l'asse x (numero progressivo)
x = np.arange(1, len(media) + 1)

# Plot con barre d'errore
plt.errorbar(x, media, yerr=err)

plt.xlabel("#Throws") #correggi, non sto plottando i throws, ma i blocchi
plt.ylabel("<r>-1/2")
plt.title(" ")

plt.grid(True)
plt.show()

# %% [markdown]
# Plot della varianza

# %%
import numpy as np
import matplotlib.pyplot as plt

# Carica i dati
data = np.loadtxt("output_v.txt")  
media = data[:, 0]-1/12  # Prima colonna (media)
err = data[:, 1]  # Seconda colonna (errore)

# Crea un array per l'asse x (numero progressivo)
x = np.arange(1, len(media) + 1)

# Plot con barre d'errore
plt.errorbar(x, media, yerr=err)

plt.xlabel("#Throws")
plt.ylabel("<r>-1/12")
plt.title(" ")

plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 01.2
# - Extend Pseudo-Random Number generator downloaded from the NSL Ariel web site and check the Central Limit Theorem:

# %% [markdown]
# 1. <font color="red">Add two probability distributions</font> by using the **method of the inversion of the cumulative distribution** to sample from a **generic** <font color="red">exponential distribution</font>, $p(x) = \lambda \exp(-\lambda x)$, $x\in [0;+\infty]$, and a **generic** <font color="red">Cauchy-Lorentz distribution</font> $p(x)=\frac{1}{\pi}\frac{\Gamma}{(x-\mu)^2+\Gamma^2}$, $x\in [-\infty;+\infty]$.

# %% [markdown]
# faccio dei plot per verificare l'andamento delle due distribuzioni scritte

# %%
import numpy as np
import matplotlib.pyplot as plt

# Carica i dati dal file
data = np.loadtxt("output_r.txt") 

# Estrai le colonne
exp_data = data[:, 1]   # seconda colonna 
cl_data = data[:, 2]    # terza colonna 

# Crea il plot
plt.figure(figsize=(12, 5))

# Istogramma della distribuzione esponenziale
plt.subplot(1, 2, 1)
plt.hist(exp_data, bins=100, density=True, alpha=0.7, color='green')
plt.title("Distribuzione Esponenziale")
plt.xlabel("x")
plt.ylabel("Densità")

# Istogramma della distribuzione di Cauchy-Lorentz
plt.subplot(1, 2, 2)
plt.hist(cl_data, bins=100, density=True, alpha=0.7, color='purple', range=(-10, 10))
plt.title("Distribuzione di Cauchy-Lorentz")
plt.xlabel("x")
plt.ylabel("Densità")

plt.tight_layout()
plt.show()

# %% [markdown]
# 2. <font color="red">Make 3 pictures</font> with the histograms obtained filling them with $10^4$ realizations of $S_N = \frac{1}{N}\sum_{i=1}^N x_i$ (for $N=1, 2, 10, 100$), being $x_i$ a random variable sampled throwing a *standard* dice (fig.1), an *exponential* dice (fig.2, use $\lambda=1$) and a *Lorentzian* dice (fig.3, use $\mu=0$ and $\Gamma=1$).
#
# Note tha you can try to fit the case $N=100$ with a Gaussian for standard and exponential dices, whereas you should use a Cauchy-Lorentz distribution for the last case.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Carica i dati dal file
data1 = np.loadtxt("output_S1.txt") 
data2 = np.loadtxt("output_S2.txt") 
data10 = np.loadtxt("output_S10.txt")
data100 = np.loadtxt("output_S100.txt") 

# Estrai le colonne
S1_data = data1[:, 1]  
S2_data = data2[:, 1]  
S10_data = data10[:, 1]  
S100_data = data100[:, 1]

S1c_data = data1[:, 2]  
S2c_data = data2[:, 2]  
S10c_data = data10[:, 2]  
S100c_data = data100[:, 2]

# Crea il plot
plt.figure(figsize=(12, 3))
#plt.title("Distribuzione esponenziale")

# Istogramma S=1
plt.subplot(1, 4, 1)
plt.hist(S1_data, bins=100, density=True, alpha=0.7, color='gold')
plt.title("N=1")
plt.xlabel("x")
plt.ylabel("Densità")

# Istogramma S=2
plt.subplot(1, 4, 2)
plt.hist(S2_data, bins=100, density=True, alpha=0.7, color='orange')
plt.title("N=2")
plt.xlabel("x")
plt.ylabel("Densità")

# Istogramma S=10
plt.subplot(1, 4, 3)
plt.hist(S10_data, bins=100, density=True, alpha=0.7, color='darkorange')
plt.title("N=10")
plt.xlabel("x")
plt.ylabel("Densità")

# Istogramma S=100
plt.subplot(1, 4, 4)
plt.hist(S100_data, bins=100, density=True, alpha=0.7, color='orangered')
plt.title("N=100")
plt.xlabel("x")
plt.ylabel("Densità")

# Fit gaussiano
mu, std = norm.fit(S100_data)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)

plt.plot(x, p, 'k', linewidth=2, label=f'Fit Gaussiano\n$\mu$={mu:.2f}, $\sigma$={std:.2f}')
plt.title("N=100")
plt.xlabel("x")
plt.ylabel("Densità")
plt.legend()

plt.tight_layout()
plt.show()



# Crea il plot
plt.figure(figsize=(12, 3))
#plt.title("Distribuzione Cauchy Lorentz")

# Istogramma S=1
plt.subplot(1, 4, 1)
plt.hist(S1c_data, bins=100, density=True, alpha=0.7, color='gold', range=(-10, 10))
plt.title("N=1")
plt.xlabel("x")
plt.ylabel("Densità")

# Istogramma S=2
plt.subplot(1, 4, 2)
plt.hist(S2c_data, bins=100, density=True, alpha=0.7, color='orange', range=(-10, 10))
plt.title("N=2")
plt.xlabel("x")
plt.ylabel("Densità")

# Istogramma S=10
plt.subplot(1, 4, 3)
plt.hist(S10c_data, bins=100, density=True, alpha=0.7, color='darkorange', range=(-10, 10))
plt.title("N=10")
plt.xlabel("x")
plt.ylabel("Densità")

# Istogramma S=100
plt.subplot(1, 4, 4)
plt.hist(S100c_data, bins=100, density=True, alpha=0.7, color='orangered', range=(-10, 10))
plt.title("N=100")
plt.xlabel("x")
plt.ylabel("Densità")



plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 01.3
# - **Simulate** the Buffon’s experiment (see LSN_Lecture_00, supplementary material):  A needle of length $L$ is thrown at random onto a horizontal plane ruled with straight lines a distance $d$ (must be $d > L$, but do not use $d\gg L$ otherwise $P\ll 1$) apart. The probability $P$ that the needle will intersect one of these lines is: $P = 2L/\pi d$. This could be used to evaluate $\pi$ from throws of the needle: if the needle is thrown down $N_{thr}$ times and is observed to land on a line $N_{hit}$ of those times, we can make an estimate of $\pi$ from
# $$\pi = \frac{2L}{Pd} = \lim_{N_{thr} \to \infty}\frac{2LN_{thr}}{N_{hit}d}$$
# <font color="red">Make a picture of the estimation of $\pi$ and its uncertainty (Standard Deviation of the mean) with a large number of *throws* $M$ as a function of the number of blocks, $N$</font> (see below: Computing statistical uncertainties). If possible, do not use $\pi$ to evaluate $\pi$.

# %% [markdown]
# ### <span style="color:blue">Computing statistical uncertainties: the blocking method</span>
# - A fundamental step in every Monte Carlo calculation is the estimation of its statistical uncertainty, **it's a must!** Your task would not be completed if you had not calculated it.

# %% [markdown]
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     In computing the statistical uncertainties, i.e. the standard deviation of the mean, you need an estimation of the variance $\sigma^2$, the second central moment. First of all note that the variance can be computed from
#     $$\sigma^2_A := \langle (A-\langle A\rangle)^2\rangle = \langle A^2 \rangle -\langle A\rangle^2 $$
#     What is the best way to estimate $\sigma^2_A$? Imagine that your Monte Carlo estimation of $A$ is obtained from a calculation which uses $M$ Monte Carlo "steps" (intentionally, here I am generic because what is a single "step" in a Monte Carlo calculation strictly depends on the specific calculation); you can always divide such $M$ Monte Carlo "steps" in $N$ blocks, with $N<M$. In each block, you can use your $M/N$ Monte Carlo "steps" to obtain an estimate of $A$, let me call it $A_i$ with $i=1,N$, and then you have also $A^2_i$ with $i=1,N$.
#     At this point everything becomes clear:
#     $$ \langle A^2 \rangle \simeq \frac{1}{N} \sum_{i=1}^N A^2_i \quad \quad \langle A\rangle^2 \simeq \left( \frac{1}{N} \sum_{i=1}^N A_i \right)^2 $$
#     and finally the statistical uncertainty with $N$ :
#     $$\frac{\sigma}{\sqrt{N-1}} \simeq \sqrt{\frac{1}{N-1} \left[ \frac{1}{N} \sum_{i=1}^N A^2_i - \left( \frac{1}{N} \sum_{i=1}^N A_i \right)^2 \right]} $$
# </p>

# %% [markdown]
# - <font color="blue">In a Monte Carlo calculation, you can use the arguments above to outputting an estimate of A and its statistical uncertainty on the fly, during your calculation. You will be able to do this every $M/N$ steps, and thus, in the end, $N$ times</font>. Note that after the first $M/N$ Monte Carlo steps, at the end of the first block, your estimation of the uncertainty is not computable, so set it to zero and compute it only from the second block. **Question**: $N$ can be chosen in many ways ... what are the limitations regarding this choice?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Carica i dati
data = np.loadtxt("output_Buffon.txt") 
lanci = data[:, 0]  # prima colonna
media = data[:, 1]-np.pi # seconda colonna (media)
err = data[:, 2]  # terza colonna (errore)


# Plot con barre d'errore
plt.errorbar(lanci, media, yerr=err)

plt.xlabel("#Throws") 
plt.ylabel("<r>-pi")
plt.title(" ")

plt.grid(True)
plt.show()
